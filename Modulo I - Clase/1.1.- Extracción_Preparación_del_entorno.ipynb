# %% [markdown]
# <div style="background: linear-gradient(120deg, #1a3a5c 0%, #2d6a9f 60%, #4a9eda 100%); padding: 28px 36px; border-radius: 14px; display: flex; align-items: center; gap: 28px; box-shadow: 0 4px 18px rgba(0,0,0,0.18);">
#     <img src='Figures/iteso.jpg' style="height: 110px; border-radius: 8px; background: white; padding: 6px; flex-shrink: 0; box-shadow: 0 2px 8px rgba(0,0,0,0.2);"/>
#     <div style="border-left: 2px solid rgba(255,255,255,0.4); padding-left: 28px;">
#         <h1 style="margin: 0 0 8px 0; color: white; font-size: 1.5em; line-height: 1.3;">Ingeniería y Ciencia de Datos</h1>
#         <h3 style="margin: 0 0 8px 0; color: white; font-size: 1.5em; line-height: 1.3;">Laboratorio de Procesamiento de Datos</h3>
#         <h3 style="margin: 0; color: rgba(255,255,255,0.8); font-weight: normal; font-size: 1.05em;">Módulo 1: Extracción de datos de diferentes fuentes</h3>
#     </div>
# </div>

# %% [markdown]
# La extracción es el primer paso para convertir información heterogénea en datos analizables. En este cuaderno se practican técnicas para leer archivos tabulares, texto libre, documentos jerárquicos, datos geoespaciales, páginas web e imágenes.
#
# > **Idea central:** extraer datos no significa únicamente abrir un archivo. Significa conservar su significado, documentar los supuestos y producir una representación útil para la siguiente etapa del flujo de ciencia de datos.
#
# ```mermaid
# flowchart LR
#     A[Fuente original] --> B[Lectura]
#     B --> C[Inspección]
#     C --> D[Limpieza y transformación]
#     D --> E[DataFrame o matriz]
#     E --> F[Análisis y modelado]
# ```

# %% [markdown]
# ## Manejo de archivos y directorios
#
# Una carpeta o directorio es una colección de archivos y directorios. Python tiene el módulo `os` que ofrece muchas herramientas útiles para trabajar con directorios y archivos.

# %%
# Configuración común para ejecutar esta sección de forma independiente
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

ruta = 'Data/'

# %%
ruta
# Out:
# 'Data/'

# %% [markdown]
# ## Preparar el entorno y las rutas
#
# Antes de leer una fuente conviene centralizar la carpeta de datos. Así se evita repetir rutas, se facilita mover el cuaderno y se hace más clara la procedencia de cada archivo.
#
# En un proyecto reproducible, la ruta debe ser relativa al proyecto o construirse con `pathlib`. En los ejemplos siguientes se conserva la variable `ruta` para trabajar con los archivos didácticos del curso.

# %%
# Almacenamos la ruta de los archivos en una variable
ruta='Data/'

# %% [markdown]
# ## El módulo `os` para gestionar rutas y archivos
#
# El módulo estándar `os` permite interactuar con el sistema operativo: consultar el directorio de trabajo, listar archivos, construir rutas portables y obtener información de cada archivo. Usarlo hace que el cuaderno funcione igual en Windows, Linux o macOS, sin depender de rutas escritas "a mano".
#
# `os.path` es especialmente útil para trabajar con rutas: `os.path.join` las construye de forma segura y `os.path.exists` verifica si un archivo existe antes de intentar abrirlo.

# %% [markdown]
# #### Obtener el directorio actual
#
# Para obtener el directorio de trabajo actual, usamos el función `getcwd()` (_get current working directory_) del módulo `os`.
#
# Esta función te devuelve el directorio actual en forma de cadena.

# %%
# Directorio de trabajo actual (desde donde se ejecuta el cuaderno)
print('Directorio actual:', os.getcwd())
# Out:
# Directorio actual: C:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026\Modulo I

# %% [markdown]
# Es importante ver que la salida dependerá del sistema operativo que estés usando. Por ejemplo, en Windows podrías obtener algo así: `C:\\usuario\\ejercicios_python`.

# %% [markdown]
# #### Listar directorios y archivos
#
# La función `listdir()` toma un directorio (_path_ o camino) y devuelve una lista con todos los archivos y subdirectorios de un directorio. Si no se le pasa ningún parámetro, devuelve los del directorio de trabajo actual.

# %%
ruta
# Out:
# 'Data/'

# %%
# Listar todos los archivos disponibles en la carpeta Data
os.listdir(ruta)
# Out:
# ['.ipynb_checkpoints',
#  'API_SI.POV.DDAY_DS2_en_excel_v2_1930012.xls',
#  'archivo_csv.csv',
#  'archivo_json.json',
#  'archivo_parquet.parquet',
#  'archivo_texto.txt',
#  'conteo_palabras.csv',
#  'csvs_ejemplo',
#  'data.json',
#  'df_tabla2.csv',
#  'ejemplo.html',
#  'Extracción.ipynb',
#  'housing_prices.csv',
#  'IFC-Subscriptions-and-Voting-Power-of-Member-Count.xml',
#  'imagen.bmp',
#  'imagen_procesada.png',
#  'inventario.txt',
#  'ITESO_entrance.jpg',
#  'json_files',
#  'metallica.json',
#  'México.min.json',
#  'plant_catalog.csv',
#  'plant_catalog.xml',
#  'productos.csv',
#  'productos.parquet',
#  'reporte_pobreza.xlsx',
#  'Salarios_minimos.csv',
#  'shp_files',
#  'tabla_1.xml',
#  'tabla_2.xml',
#  'texto_1.txt',
#  'texto_2.txt',
#  'texto_3.txt']

# %% [markdown]
# #### Cambiar el directorio de trabajo
#
# Se puede cambiar de directorio usando la función `chdir()` (_change directory_). Los directorios pueden ser relativos o absolutos (en sistemas operativos basados en Unix '.' es el directorio actual, '..' es el anterior, '/' es el directorio raíz).
#
# Ejemplo:
# ```python
# >>> os.chdir('../Inicial')              # entro en ../Inicial
# >>> print(os.getcwd())
# /home/usuario/ejercicios_python/Data
# >>> os.chdir('..')                  # subo un nivel
# >>> os.chdir('..')                  # subo otro nivel
# >>> print(os.getcwd())
# /home/usuario/
# >>> os.chdir('C:/')
# >>> print(os.getcwd())
# C:/
# ```
#
# Para cambiar de directorio, se añade el nuevo directorio como cadena a esta función.

# %%
os.chdir('../Inicial') #Entramos en ../Inicial
print(os.getcwd())
# Out:
# C:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026\Inicial

# %%
os.chdir('..')  # subo un nivel

# %%
os.chdir('..')

# %%
print(os.getcwd())
# Out:
# C:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos

# %%
os.chdir('C:/Users/uie70742/OneDrive - ITESO/ITESO/')

# %%
print(os.getcwd())
# Out:
# C:\Users\uie70742\OneDrive - ITESO\ITESO

# %% [markdown]
# En diferentes sistemas operativos las barras de directorio se escriben de diferentes maneras. Es recomendable usar el comando `os.path.join` como en el siguiente ejemplo de manera que el código funcione independientemente del sistema operativo que se este usando.

# %%
directorio = os.path.join('c:\\', 'Users','uie70742','OneDrive - ITESO','ITESO', 'Ingeniería y Ciencia de Datos','Laboratorio_de_Procesamiento_de_Datos_02026')
os.chdir(directorio)

# %%
print(os.getcwd())
# Out:
# c:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026

# %% [markdown]
# Usar directorios relativos al actual (que comienzan con './') y no absolutos (que comienzan con '/') facilita la portabilidad del código de una computadora a otra.

# %%
# Construir la ruta a un archivo de forma portable con os.path.join
ruta_csv = os.path.join(ruta, 'df_tabla2.csv')
print('Ruta construida:', ruta_csv)
print('¿Existe el archivo?', os.path.exists(ruta_csv))
# Out:
# Ruta construida: Data/df_tabla2.csv
# ¿Existe el archivo? False

# %%
# Separar los componentes de una ruta
print('Directorio       :', os.path.dirname(ruta_csv))
print('Nombre de archivo:', os.path.basename(ruta_csv))
print('Nombre y extensión:', os.path.splitext(os.path.basename(ruta_csv)))
# Out:
# Directorio       : Data
# Nombre de archivo: df_tabla2.csv
# Nombre y extensión: ('df_tabla2', '.csv')

# %% [markdown]
# ##### Ejemplo: Filtrar únicamente los archivos .txt de la carpeta Data

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'environment.yml', 'Inicial', 'INSTALACION.md', 'INSTALACION_ENTORNO.md', 'LICENSE', 'Lista_Alumnos', 'Modulo I', 'Modulo I - ClaseGuia', 'Modulo II', 'Modulo III', 'README.md', 'requirements.txt']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\uie70742\\OneDrive - ITESO\\ITESO\\Ingeniería y Ciencia de Datos\\Laboratorio_de_Procesamiento_de_Datos_02026'

# %%
#os.chdir(os.path.join(os.getcwd(),'Modulo I'))

# %%
print(os.getcwd())
# Out:
# c:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026

# %%
# Filtrar únicamente los archivos .txt de la carpeta Data
archivos_txt = [f for f in os.listdir(ruta) if f.endswith('.txt')]
archivos_txt
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Filtrar únicamente los archivos .txt de la carpeta Data
# ----> 2 archivos_txt = [f for f in os.listdir(ruta) if f.endswith('.txt')]
#       3 archivos_txt
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'Data/'

# %%
ruta

# %%
# Tamaño (en bytes) de cada archivo de texto
for nombre in archivos_txt:
    ruta_completa = os.path.join(ruta, nombre)
    print(f'{nombre}: {os.path.getsize(ruta_completa)} bytes')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Tamaño (en bytes) de cada archivo de texto
# ----> 2 for nombre in archivos_txt:
#       3     ruta_completa = os.path.join(ruta, nombre)
#       4     print(f'{nombre}: {os.path.getsize(ruta_completa)} bytes')
#
# NameError: name 'archivos_txt' is not defined

# %% [markdown]
# #### Crear un nuevo directorio
#
# Podemos crear un directorio con la función `mkdir()`.
#
# Esta función toma como argumento el path del nuevo directorio. Si no se especifica el path absoluto, el directorio nuevo se crea en el directorio de trabajo actual.

# %%
print(os.getcwd())
# Out:
# c:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026

# %%
os.mkdir('test')          # creo el directorio test
os.mkdir(os.path.join('test', 'carpeta'))  # creo el subdirectorio carpeta dentro de test
print(os.listdir('test'))
# Out:
# ['carpeta']

# %% [markdown]
# #### Renombrar un directorio o un archivo
#
# Para renombrar un directorio o archivo, la función `rename()` toma dos argumentos, el viejo nombre y el nuevo nombre.

# %%
os.chdir('test')                     # entro en el directorio test
print(os.listdir())
# Out:
# ['carpeta']

# %%
os.getcwd()
# Out:
# 'c:\\Users\\uie70742\\OneDrive - ITESO\\ITESO\\Ingeniería y Ciencia de Datos\\Laboratorio_de_Procesamiento_de_Datos_02026\\test'

# %%
os.rename('carpeta','carpeta_nueva') # cambio el nombre de carpeta
print(os.listdir())
# Out:
# ['carpeta_nueva']

# %% [markdown]
# Esto mismo se puede hacer trabajando desde el directorio `Ejercicios`, sin entrar en 'test', marcando el camino hacia la carpeta que queremos renombrar.

# %%
os.chdir('..')                          # subo un nivel

# %%
os.getcwd()
# Out:
# 'c:\\Users\\uie70742\\OneDrive - ITESO\\ITESO\\Ingeniería y Ciencia de Datos\\Laboratorio_de_Procesamiento_de_Datos_02026'

# %%
print(os.listdir('test'))                      # miro qué hay en test
# Out:
# ['carpeta_nueva']

# %%
os.rename(os.path.join('test', 'carpeta_nueva'), os.path.join('test','carpeta_vieja'))
print(os.listdir('test'))
# Out:
# ['carpeta_vieja']

# %% [markdown]
# La función `rename()` también es útil para mover un archivo o directorio, cambiando el camino (_path_) de acceso al archivo. Probemos hacer lo siguiente:

# %%
os.rename(os.path.join('test','carpeta_vieja'), 'carpeta_vieja') # cambio el path
print(os.listdir('test'))
# Out:
# []

# %% [markdown]
# La carpeta 'carpeta' ahora se encuentra en 'Modulo I', y no dentro de 'Modulo I/test'.
#
# **Ojo**: `rename()` funciona cuando el archivo (o directorio) no se cambia de disco (o más específicamente de una partición). Si se necesita mover un archivo del disco a un pendrive, por ejemplo, lo correcto es copiar el archivo al pendrive y luego borrarlo del disco. `rename()` no hace esto: no copia y borra, simplemente cambia el nombre. Para renombrar en caso que se pueda o copiar y borrar si lo primero no es posible, podemos usar la función `move()` del módulo `shutil`. Este módulo es de más alto nivel y usa las primitivas de bajo nivel del módulo `os`. Al usar `os` tenemos un control más estricto de las operaciones. Las funciones de `shutil` pueden resultar más cómodas, pero en el camino pueden invocar a diversas funciones de bajo nivel del módulo `os`.

# %% [markdown]
# #### Eliminar un directorio o un archivo
#
# > :warning: **A continuación usaremos comandos que borran archivos sin pasar por ninguna papelera de reciclaje. Estas acciones no pueden deshacerse**: Usar con precaución, _un gran poder conlleva una gran responsabilidad_.
#
# Podemos eliminar un archivo usando la función `remove()`. También podemos eliminar un directorio vacío usando `rmdir()`.
#
# En el siguiente código trabajaremos en una carpeta que tiene esta estructura:
# ```
# otra_carpeta
# ├── archivo.txt
# └── subcarpeta
# ```

# %%
os.chdir('Carpeta_SinImportancia') 
print(os.getcwd())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 os.chdir('Carpeta_SinImportancia')
#       2 print(os.getcwd())
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Carpeta_SinImportancia'

# %%
print(os.listdir())
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'carpeta_vieja', 'environment.yml', 'Inicial', 'INSTALACION.md', 'INSTALACION_ENTORNO.md', 'LICENSE', 'Lista_Alumnos', 'Modulo I', 'Modulo I - ClaseGuia', 'Modulo II', 'Modulo III', 'README.md', 'requirements.txt', 'test']

# %%
os.remove('archivo1.txt')    # elimino el archivo
print(os.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 os.remove('archivo1.txt')    # elimino el archivo
#       2 print(os.listdir())
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'archivo1.txt'

# %%
os.rmdir('SubCarpeta')
print(os.listdir())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 os.rmdir('SubCarpeta')
#       2 print(os.listdir())
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'SubCarpeta'

# %% [markdown]
# **Ojo**: `rmdir()` solamente puede borrar directorios si están vacíos. Para eliminar un directorio no vacío, podemos usar `rmtree()` del módulo `shutil`.

# %%
os.chdir('..')

# %%
print(os.getcwd())
# Out:
# c:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos

# %%
os.mkdir(os.path.join('test','carpeta'))                # creo nuevamente una carpeta
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 os.mkdir(os.path.join('test','carpeta'))                # creo nuevamente una carpeta
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'test\\carpeta'

# %%
os.mkdir(os.path.join('test','carpeta', 'subcarpeta'))  # creo una subcarpeta en carpeta
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 os.mkdir(os.path.join('test','carpeta', 'subcarpeta'))  # creo una subcarpeta en carpeta
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'test\\carpeta\\subcarpeta'

# %%
os.chdir('test')                                        # entro en test
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 os.chdir('test')                                        # entro en test
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'test'

# %%
os.rmdir('carpeta')                                     # quiero eliminar carpeta
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 os.rmdir('carpeta')                                     # quiero eliminar carpeta
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'carpeta'

# %%
import shutil

# %%
shutil.rmtree('carpeta')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 shutil.rmtree('carpeta')
#
# File ~\.conda\envs\ic_curso_2026\lib\shutil.py:750, in rmtree(path, ignore_errors, onerror)
#     748     # can't continue even if onerror hook returns
#     749     return
# --> 750 return _rmtree_unsafe(path, onerror)
#
# File ~\.conda\envs\ic_curso_2026\lib\shutil.py:601, in _rmtree_unsafe(path, onerror)
#     599         entries = list(scandir_it)
#     600 except OSError:
# --> 601     onerror(os.scandir, path, sys.exc_info())
#     602     entries = []
#     603 for entry in entries:
#
# File ~\.conda\envs\ic_curso_2026\lib\shutil.py:598, in _rmtree_unsafe(path, onerror)
#     596 def _rmtree_unsafe(path, onerror):
#     597     try:
# --> 598         with os.scandir(path) as scandir_it:
#     599             entries = list(scandir_it)
#     600     except OSError:
# ...

# %%
os.listdir()
# Out:
# ['Actividad_1_Repaso_Python.ipynb',
#  'ImagenPrincipal.png',
#  'Laboratorio_de_Procesamiento_de_Datos_02026',
#  'MAF3658A-19082026_140707.xls',
#  'Material Laboratorio de Procesamiento de Datos']

# %% [markdown]
# #### Recorriendo directorios con `os.walk()`
#
# La función `walk()` del módulo `os` genera una lista con los nombres de todos los archivos del árbol de subdirectorios de un directorio dado. Es decir, lista los archivos de un directorio dado y luego entra en cada subdirectorio y hace lo mismo, recursivamente (_top-down_).
#
# La función `walk()` recibe como único parámetro obligatorio el directorio donde comenzar a mirar (la raíz del árbol).
#
# ##### Ejemplo
#
# En este ejemplo se ve cómo se usa `os.walk()`.
#
# ```python
# import os
# for root, dirs, files in os.walk("."):
#    for name in files:
#       print(os.path.join(root, name))
#    for name in dirs:
#       print(os.path.join(root, name))
# ```

# %% [markdown]
# `os.walk` recorre un directorio junto con todos sus subdirectorios. Es útil para localizar archivos en estructuras de carpetas anidadas.

# %%
directorio = os.path.join('c:\\', 'Users','uie70742','OneDrive - ITESO','ITESO', 'Ingeniería y Ciencia de Datos','Laboratorio_de_Procesamiento_de_Datos_02026','Modulo I')
os.chdir(directorio)
print(os.getcwd())
# Out:
# c:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026\Modulo I

# %%
# Recorrer la carpeta Data y sus subcarpetas
for carpeta_actual, subcarpetas, archivos in os.walk(ruta):
    print('Carpeta:', carpeta_actual)
    print('  Subcarpetas:', subcarpetas)
    print('  Archivos:', archivos)
# Out:
# Carpeta: Data/
#   Subcarpetas: ['.ipynb_checkpoints', 'csvs_ejemplo', 'json_files', 'shp_files']
#   Archivos: ['API_SI.POV.DDAY_DS2_en_excel_v2_1930012.xls', 'archivo_csv.csv', 'archivo_json.json', 'archivo_parquet.parquet', 'archivo_texto.txt', 'conteo_palabras.csv', 'data.json', 'df_tabla2.csv', 'ejemplo.html', 'Extracción.ipynb', 'housing_prices.csv', 'IFC-Subscriptions-and-Voting-Power-of-Member-Count.xml', 'imagen.bmp', 'imagen_procesada.png', 'inventario.txt', 'ITESO_entrance.jpg', 'metallica.json', 'México.min.json', 'plant_catalog.csv', 'plant_catalog.xml', 'productos.csv', 'productos.parquet', 'reporte_pobreza.xlsx', 'Salarios_minimos.csv', 'tabla_1.xml', 'tabla_2.xml', 'texto_1.txt', 'texto_2.txt', 'texto_3.txt']
# Carpeta: Data/.ipynb_checkpoints
#   Subcarpetas: []
#   Archivos: ['data-checkpoint.json', 'imagen-checkpoint.bmp']
# Carpeta: Data/csvs_ejemplo
#   Subcarpetas: []
# ...

# %%
for carpeta_actual, subcarpetas, archivos in os.walk(directorio):
    print('Carpeta:', carpeta_actual)
    print('  Subcarpetas:', subcarpetas)
    print('  Archivos:', archivos)
# Out:
# Carpeta: c:\Users\uie70742\OneDrive - ITESO\ITESO\Ingeniería y Ciencia de Datos\Laboratorio_de_Procesamiento_de_Datos_02026\Modulo I
#   Subcarpetas: ['.ipynb_checkpoints', 'Carpeta_SinImportancia', 'carpeta_vieja', 'COVID_INDIA_POC-shp', 'Data', 'Figures', 'test']
# ...

# %% [markdown]
# ### Práctica de Laboratorio: Manejo de Archivos y Directorios

# %% [markdown]
# 1. Los scripts del mundo real a menudo necesitan crear jerarquías de carpetas profundas en un solo paso, por ejemplo, al organizar la salida por fecha **(logs/2025/06/10)** o estructura del proyecto. Dado un path (un string) construir una función que cree una estructura de directorios anidados en el directorio de trabajo actual, incluso si algunos o todos los directorios padres aún no existen.
#
# Ejemplo:
# - *Entrada* folders_path = "a/b/c"
# - *Salida*: En el directorio actual:
#
# ```
# a
# ├── b
#     └── c
# ```

# %%
def crear_directorio(folders_path=''):
    #try: except:
    #if(folders_path es un string) else: 
    folders = folders_path.split('/')
    cdir = ''
    for f in folders:
        cdir = os.path.join(cdir, f)
        os.makedirs(cdir, exist_ok = True)

# %%
crear_directorio(folders_path='d/e/f')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 crear_directorio(folders_path=2165)
#
# Cell In[55], line 2, in crear_directorio(folders_path)
#       1 def crear_directorio(folders_path=''):
# ----> 2     folders = folders_path.split('/')
#       3     cdir = ''
#       4     for f in folders:
#
# AttributeError: 'int' object has no attribute 'split'

# %%
os.makedirs(c_p, exist_ok = True)

# %%
os.makedirs('carp1', exist_ok = True)

# %%
folders_path = "a/b/c"

# %%
folders = folders_path.split('/')
folders
# Out:
# ['a', 'b', 'c']

# %%
for f in folders:

# %%
folders_path
# Out:
# 'a/b/c'

# %%
os.makedirs(folders_path, exist_ok = True)
